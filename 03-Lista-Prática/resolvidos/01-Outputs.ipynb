# %% [markdown]
# # ✎ᝰ Lista 1: Comunicação com o Usuário (Saída)
#
# ### 1. Exiba "Olá, Mundo!".

# %%
print("Olá, Mundo!")
# Out:
# Olá, Mundo!

# %% [markdown]
# ### 2. Exiba o número 100.

# %%
print(100)
# Out:
# 100

# %% [markdown]
# ### 3. Exiba seu nome.

# %%
print("Julia Antoni")
# Out:
# Julia Antoni

# %% [markdown]
# ### 4. Exiba o resultado de 10 + 5 diretamente no print.

# %%
print(10+5)
# Out:
# 15

# %% [markdown]
# ### 5. Exiba duas palavras separadas por uma vírgula dentro do mesmo print.

# %%
print("palavra1", "palavra2")
# Out:
# palavra1 palavra2

# %% [markdown]
# ### 6. Exiba três frases em linhas diferentes usando três print().

# %%
print("frase1")
print("frase2")
print("frase3")
# Out:
# frase1
# frase2
# frase3

# %% [markdown]
# ### 7. Exiba o nome de uma cor.

# %%
print("Branco")
# Out:
# Branco

# %% [markdown]
# ### 8. Exiba o número 3.14.

# %%
print(3.14)
# Out:
# 3.14

# %% [markdown]
# ### 9. Exiba a frase "Estou aprendendo Python".

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %% [markdown]
# ### 10. Exiba o resultado de 2 * 50.

# %%
print(2*50)
# Out:
# 100
