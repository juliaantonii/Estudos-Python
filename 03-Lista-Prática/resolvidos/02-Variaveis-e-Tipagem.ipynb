# %% [markdown]
# # ✎ᝰ Lista 2: Variáveis e Tipagem
#
# ### 1. Crie x = 10 e exiba type(x).

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ### 2. Crie y = "Oi" e exiba type(y).

# %%
y = "Oi"
print(type(y))
# Out:
# <class 'str'>

# %% [markdown]
# ### 3. Crie z = 4.5 e exiba type(z).

# %%
z = 4.5
print(type(z))
# Out:
# <class 'float'>

# %% [markdown]
# ### 4. Crie w = True e exiba type(w).

# %%
w = True
print(type(w))
# Out:
# <class 'bool'>

# %% [markdown]
# ### 5. Substitua o valor de x por "Dez" e exiba o novo tipo.

# %%
x = "Dez"
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# ### 6. Crie a = 5 e b = 5.0. Exiba os tipos de ambos.

# %%
a = 5
b = 5.0
print(type(a), type(b))
# Out:
# <class 'int'> <class 'float'>

# %% [markdown]
# ### 7. Declare uma variável nome_completo e atribua seu nome.

# %%
nome_completo = "Julia Antoni"

# %% [markdown]
# ### 8. Declare idade = 20.

# %%
idade = 20

# %% [markdown]
# ### 9. Exiba a soma de duas variáveis numéricas.

# %%
var1 = 10
var2 = 20
print(var1 + var2)
# Out:
# 30

# %% [markdown]
# ### 10. Crie uma variável para armazenar o nome de uma cidade e exiba-a.

# %%
cidade = "São Paulo"
print(cidade)
# Out:
# São Paulo
